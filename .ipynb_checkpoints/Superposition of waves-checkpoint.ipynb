# %% [markdown]
# # Simulating the superposition of two waves

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath

# %% [markdown]
# This worksheet you will look at the superposition for two infinite plane waves with the same wavelength and frequency crossing each other at different angles while travelling in the x y plane. First, define the wavelength, `wvl` ($\lambda$), the angles the two propagation vectors make with the x-axis, `theta1` and `theta2` ($\theta_1 \theta_2$) and the amplitudes of the two waves `A1` and `A2` ($E_1 E_2$)

# %%
wvl = 0.600
theta1 = 0.1*math.pi
theta2 = -0.1*math.pi
k = 2*math.pi / wvl
E1 = 1
E2 = 1

# %% [markdown]
# Form the wavevectors $k_1$ and $k_2$ you have the angle the vectors make and their magnitude. You will use numpy arrays for the two vectors.

# %%
k1 = np.array([k * math.cos(theta1),k * math.sin(theta1)])
k2 = np.array([k * math.cos(theta2),k * math.sin(theta2)])

# %% [markdown]
# We are going to plot the intensities of the resulting waveform over the xy plane so we need a set of x values and y values and also an empty 2D array to hold the results

# %%
xs = np.linspace(0,50,500)
ys = np.linspace(-25,25,500)

# %% [markdown]
# For each point in the 2D plane you just defined you are going to calculate the sum of the two waves:
#
# $ E = E_1 e^{i(\vec{k_1} \cdot \vec{r}-\omega t)} + E_2 e^{i( \vec{k_2} \cdot \vec{r} -\omega t)} $
#
# The code below steps over the range of x and y values we just created, calculating the intensity at each point.
#
# _Note on equations: the intensity formula should be $\frac{1}{2} \varepsilon_0 c EE^{\ast}$ but we are just setting $\frac{1}{2} \varepsilon_0 c= 1$ because we are only interested in relative intensity._
#
# _Note on programming: on the last line we have to take the real part of $zz^{\ast}$. Mathematically this isn't necessary as the result of that product is always real, but python treats the result as a complex number with zero imaginary part and some of the plotting functions don't like that._

# %%
def add2planeWaves(k1,k2,x,y):
    intensity = np.empty((x.size,y.size))

    for rx in range(x.size):
        for ry in range(y.size):
            # Make the 'r' vector (this is just a location in space)
            r = np.array([x[rx],y[ry]])
            # Calculate the phase for each wave - note we are setting t=0 so we ignore the time part
            phase1 = k1.dot(r)
            phase2 = k2.dot(r)
            # Create the complex waves
            z1 = cmath.rect(E1,phase1)
            z2 = cmath.rect(E2,phase2)
            # Add the waves
            z = z1 + z2
            # Calculate the intensity and save it for that point
            intensity[rx,ry] = (z * z.conjugate()).real
    
    return intensity

# %% [markdown]
# This plots the intensity over the xy plane

# %%
intensity = add2planeWaves(k1,k2,xs,ys)

# %%
plt.imshow(intensity.T,extent=[0,50,-25,25])
# .T takes the transpose of the array. Necessary as by default imshow would flip the x and y axes

# %% [markdown]
# You can also plot a graph of the intensity through a slice in the y direction. Writing `intensity[4]` here takes the 5th x value  of the array and plots it against the y-values

# %%
plt.plot(ys,intensity[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# ## Task 1:
#
# Redo the caluclation with different values for the angles of the two k-vectors. Try them at angles which are symmetric about the x axis and asymmetric. Also find out what happens if the two vectors are 180 degrees out from each other. Answer the following questions:
# * In what direction do the intensity bands go in relation to the k-vectors?
# * What angular difference produces the largest and smallest spatial frequency?
# * What effect does changing one of the wave amplitudes have on the intensity profile (check this in the slice plot.
# * What is the effect of changing the wavelength?

# %% [markdown]
# Recalcuating with new angles symmetric abou the x-axis.

# %%
theta3 = 0.025*math.pi
theta4 = -0.025*math.pi
k3 = np.array([k * math.cos(theta3),k * math.sin(theta3)])
k4 = np.array([k * math.cos(theta4),k * math.sin(theta4)])
intensity34 = add2planeWaves(k3,k4,xs,ys)
plt.imshow(intensity34.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity34[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Recalcuating with a change in the in the amplitude.

# %%
E1=3
E2=3
intensity34a = add2planeWaves(k3,k4,xs,ys)
plt.imshow(intensity34a.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity34a[4])
plt.ylim([0,40])
# Out:
# (0.0, 40.0)

# %% [markdown]
# Recaculating the above wave but with waves of different applitudes.

# %%
E1=3
E2=10
intensity34b = add2planeWaves(k3,k4,xs,ys)
plt.imshow(intensity34b.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity34b[4])
plt.ylim([20,200])
# Out:
# (20.0, 200.0)

# %% [markdown]
# Resetting the waves to have identical amplitudes.

# %%
E1 =1
E2 =1

# %% [markdown]
# Recalcuating with new angles asymmetric abou the x-axis.

# %%
theta5 = 0.08*math.pi
theta6 = -0.05*math.pi
k5 = np.array([k * math.cos(theta5),k * math.sin(theta5)])
k6 = np.array([k * math.cos(theta6),k * math.sin(theta6)])
intensity56 = add2planeWaves(k5,k6,xs,ys)
plt.imshow(intensity56.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity56[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Recalcuating with new angles symmetric about the x-axis but 180 degrees of each other.

# %%
theta7 = 0.5*math.pi
theta8 = -0.5*math.pi

k7 = np.array([k * math.cos(theta7),k * math.sin(theta7)])
k8 = np.array([k * math.cos(theta8),k * math.sin(theta8)])
intensity78 = add2planeWaves(k7,k8,xs,ys)
plt.imshow(intensity78.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity78[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Recalcuating with new angles symmetric about the x-axis but 180 degrees of each other but with a change to the wavelength as the previous sample shows aliasing.

# %%
theta9 = 0.5*math.pi
theta10 = -0.5*math.pi
wvl910 = 2.600
k910 = 2*math.pi / wvl910

k9 = np.array([k910 * math.cos(theta9),k910 * math.sin(theta9)])
k10 = np.array([k910 * math.cos(theta10),k910 * math.sin(theta10)])
intensity910 = add2planeWaves(k9,k10,xs,ys)
plt.imshow(intensity910.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity910[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Recalcuating with new angles symmetric about the x-axis but 90 degrees of each other.

# %%
theta11 = 0.25*math.pi
theta12 = -0.25*math.pi
wvl1112 = 2.600
k1112= 2*math.pi / wvl1112

k11 = np.array([k1112 * math.cos(theta11),k1112 * math.sin(theta11)])
k12 = np.array([k1112 * math.cos(theta12),k1112 * math.sin(theta12)])
intensity1112 = add2planeWaves(k11,k12,xs,ys)
plt.imshow(intensity1112.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity1112[4])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# * In what direction do the intensity bands go in relation to the k-vectors?
#
# If the vectors are symmetric about the axis the intensity bands remain horizontal. Once the k vectors are asymetrical about the x-axis they create an angle to the x-axis.
#
# * What angular difference produces the largest and smallest spatial frequency?
#
# The largest spacial frequency is when the angular difference is the smallest. The smallest spacial frequency is when the angular difference is 180 degrees.
#
# * What effect does changing one of the wave amplitudes have on the intensity profile (check this in the slice plot.
#
# Increasing the amplitude of the waves equally of waves with the same amplitudes increases the intensity peaks but zero intensity can still happen. When the amplitudes are not equal, the intensity wave shifts off the zero mark and the wave intensity can no longer be zero.
#
# * What is the effect of changing the wavelength?
#
# Increasing the wavelength, increases the intensity bands. This makes sense since a longer wavelenth means that the intensity will last longer.

# %% [markdown]
# # Task 2: Spherical waves
#
# What if instead of plane waves we have two spherical waves? Rewrite the plane wave function above to simulate two spherical waves. Spherical waves are given by the equation:
#
# $E = \frac{E_0}{d} e^{i(\vec{k_1} \cdot \vec{r}-\omega t)} $
#
# The difference here is the k-vector is now different for every point as it radiates from a single point. You will need to define a vector for where the source point is for the two waves. Call them `s1` and `s2`. ($\vec{s_1}$ and $\vec{s_2}$).  The k vector will point in the direction from the s-vector to the r vector. So your function will have to calculate the direction of the k-vector for each r point before doing the dot product.
# The other difference is the $d$ is not the actual distance from the source point to the r-point so your function will need to calculate that too.
# A final difficulty: you must avoid the singularity! As d goes to zero the amplitude becomes infinite. Even if it's close the size of the amplitude will dwarf the interference pattern. Suggestion: work out d first and if it is more  than say 3 times E_0 just set it to 3 times E_0.
#
# Try the simulation as before for some different source positions.

# %%
wvl_sphere = 0.600
k = 2*math.pi / wvl_sphere
E_1 = 1
E_2 = 1
s1 = np.array([40,5])
s2 = np.array([5,2])

# %%
def add2sphericalWaves(k,s1,s2,x,y):
    intensity = np.empty((x.size,y.size))

    for rx in range(x.size):
        for ry in range(y.size):
            # Make the 'r' vector (this is just a location in space)
            r = np.array([x[rx],y[ry]])
            # Calculate the distance from s1 to r 
            d1 = r - s1
            d1_mag = math.sqrt(d1.dot(d1))
            # Calculate the distance from s2 to r
            d2 = r - s2
            d2_mag = math.sqrt(d2.dot(d2))
            # (if d is small set amplitude to high, square it and set the intesity directly)
            if d1_mag < E_1:
                d1_mag = E_1
            if d2_mag < E_2:
                d2_mag = E_2  
            # Calculate the k1 vector
            k1 = k*d1/d1_mag
            # Calculate the k2 vector
            k2 = k*d2/d2_mag
            # Calculate the phase for each wave - note we are setting t=0 so we ignore the time part
            phase1_sphere = k1.dot(d1)
            phase2_sphere = k2.dot(d2)
            # Create the complex waves
            z1_sphere = cmath.rect(E_1,phase1_sphere)
            z2_sphere = cmath.rect(E_2,phase2_sphere)
            # Add the waves
            z_sphere = z1_sphere + z2_sphere
            # Calculate the intensity and save it for that point
            
            intensity[rx,ry] = (z_sphere * z_sphere.conjugate()).real
    
    return intensity

# %%
intensity_sphere = add2sphericalWaves(k,s1,s2,x,y)

# %%
plt.imshow(intensity_sphere.T,extent=[0,50,-25,25])

# %%
plt.plot(ys,intensity_sphere[25])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Putting 2 light sources close at the same x positions and same distance from the x axis to see how the intensity behaves at very long distance away.

# %%
s1 = np.array([-500,5])
s2 = np.array([-500,-5])

# %%
intensity_sphere2 = add2sphericalWaves(k,s1,s2,x,y)

# %%
plt.imshow(intensity_sphere2.T,extent=[0,500,-100,100])

# %%
plt.plot(ys,intensity_sphere2[499])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)

# %%
wvl_sphere = 0.05
k = 2*math.pi / wvl_sphere
s1 = np.array([-500,5])
s2 = np.array([-500,-5])

# %%
intensity_sphere3 = add2sphericalWaves(k,s1,s2,x,y)

# %%
plt.imshow(intensity_sphere3.T,extent=[0,500,-100,100])

# %%
plt.plot(ys,intensity_sphere3[499])
plt.ylim([-1,5])
# Out:
# (-1.0, 5.0)
